# %%
import json
import jieba
import pandas as pd
import numpy as np
import random
import csv
import operator
import math
from argparse import ArgumentParser
from collections import Counter

# %%
with open("inverted_file.json") as f:
    invert_file = json.load(f)
with open('url2content.json') as f:
    file_content = json.load(f)

# %%
# read query and news corpus
querys = np.array(pd.read_csv("QS_1.csv")) # [(query_id, query), (query_id, query) ...]
corpus = np.array(pd.read_csv("NC_1.csv")) # [(news_id, url), (news_id, url) ...]
rlv = np.array(pd.read_csv("news_data_1/TD.csv"))
num_corpus = corpus.shape[0] # used for random sample
print(num_corpus)
# Out:
# 100000

# %%
dlen = dict()
avdl = 0
for news_id, url in corpus:
    l = len(file_content[url])
    avdl += l
    dlen[news_id] = l
avdl /= corpus.shape[0]
print(avdl)
# Out:
# 738.53705

# %%
k = 1.2
b = 0.75
test = pd.DataFrame()
# process each query

final_ans = []
new_final_ans = []
for (query_id, query) in querys:
    print("query_id: {}".format(query_id))
    rel = rlv[rlv[:,0]==query]
    # counting query term frequency
    query_cnt = Counter()
    query_words = list(jieba.cut(query))
    query_cnt.update(query_words)

    # calculate scores by tf-idf
    document_scores = dict() # record candidate document and its scores
    for (word, count) in query_cnt.items():
        if word in invert_file:
            query_tf = count
            idf = math.log(invert_file[word]['idf'])
            
            qw = query_tf
            for document_count_dict in invert_file[word]['docs']:
                for doc, doc_tf in document_count_dict.items():
                    doc_tf = (k+1)*doc_tf/(doc_tf+k*(1-b+b*(dlen[doc]/avdl)))
                    dw = doc_tf
                    if doc in document_scores:
                        document_scores[doc] += dw * idf
                    else:
                        document_scores[doc] = dw * idf
                    #print(document_scores[doc])

    #for doc, score in document_scores.items():
        #document_scores[doc] /= (math.sqrt(dn[doc]) * math.sqrt(qn))
    sorted_document_scores = sorted(document_scores.items(), key=operator.itemgetter(1), reverse=True)
    
    if len(sorted_document_scores) >= 300:
        final_ans.append([doc_score_tuple[0] for doc_score_tuple in sorted_document_scores[:300]])
    else: 
        documents_set  = set([doc_score_tuple[0] for doc_score_tuple in sorted_document_scores])
        sample_pool = ['news_%06d'%news_id for news_id in range(1, num_corpus+1) if 'news_%06d'%news_id not in documents_set]
        sample_ans = random.sample(sample_pool, 300-count)
        sorted_document_scores.extend(sample_ans)
        final_ans.append([doc_score_tuple[0] for doc_score_tuple in sorted_document_scores])
# Out:
# query_id: q_01
# query_id: q_02
# query_id: q_03
# query_id: q_04
# query_id: q_05
# query_id: q_06
# query_id: q_07
# query_id: q_08
# query_id: q_09
# query_id: q_10
# query_id: q_11
# query_id: q_12
# query_id: q_13
# query_id: q_14
# query_id: q_15
# query_id: q_16
# query_id: q_17
# query_id: q_18
# query_id: q_19
# query_id: q_20

# %%
MAP = 0
count = 0
# write answer to csv file
with open("sample_output.csv", 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    head = ['Query_Index'] + ['Rank_%03d'%i for i in range(1,301)]
    writer.writerow(head)
    for query_id, ans in enumerate(final_ans, 1):
        query = querys[query_id-1, 1]
        rel = rlv[rlv[:,0]==query]
        print(rel)
        avgp = 0
        p = 0
        if len(rel): # query is in TD.csv
            count += 1
            for i, t in enumerate(ans):
                if t in rel[:, 1] and rel[rel[:, 1]==t][0, 2]:
                    p += 1
                    avgp += p/(i+1)
            avgp /= min(300, len(rel[rel[:,2]>0]))
            print(avgp)
            MAP += avgp


        writer.writerow(['q_%02d'%query_id]+ans)
print('MAP = {}'.format(MAP/count))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [['支持陳前總統保外就醫' 'news_064209' 2]
#  ['支持陳前總統保外就醫' 'news_012873' 1]
#  ['支持陳前總統保外就醫' 'news_056765' 3]
#  ['支持陳前總統保外就醫' 'news_055305' 1]
#  ['支持陳前總統保外就醫' 'news_097573' 3]
#  ['支持陳前總統保外就醫' 'news_027172' 1]
#  ['支持陳前總統保外就醫' 'news_082981' 1]
#  ['支持陳前總統保外就醫' 'news_077798' 3]
#  ['支持陳前總統保外就醫' 'news_089045' 2]
#  ['支持陳前總統保外就醫' 'news_083857' 1]
#  ['支持陳前總統保外就醫' 'news_047289' 2]
#  ['支持陳前總統保外就醫' 'news_049601' 2]
#  ['支持陳前總統保外就醫' 'news_086103' 3]
#  ['支持陳前總統保外就醫' 'news_008928' 1]
#  ['支持陳前總統保外就醫' 'news_032480' 1]
#  ['支持陳前總統保外就醫' 'news_094510' 2]
#  ['支持陳前總統保外就醫' 'news_078179' 2]
#  ['支持陳前總統保外就醫' 'news_044938' 2]
#  ['支持陳前總統保外就醫' 'news_019675' 2]
#  ['支持陳前總統保外就醫' 'news_050066' 1]
#  ['支持陳前總統保外就醫' 'news_012956' 3]
#  ['支持陳前總統保外就醫' 'news_020883' 2]
#  ['支持陳前總統保外就醫' 'news_048753' 3]
#  ['支持陳前總統保外就醫' 'news_035402' 2]
#  ['支持陳前總統保外就醫' 'news_035655' 3]
#  ['支持陳前總統保外就醫' 'news_009430' 2]
#  ['支持陳前總統保外就醫' 'news_084359' 1]
#  ['支持陳前總統保外就醫' 'news_030929' 1]
#  ['支持陳前總統保外就醫' 'news_039199' 2]
#  ['支持陳前總統保外就醫' 'news_062906' 3]
#  ['支持陳前總統保外就醫' 'news_096516' 3]
#  ['支持陳前總統保外就醫' 'news_003329' 3]
#  ['支持陳前總統保外就醫' 'news_001836' 3]
#  ['支持陳前總統保外就醫' 'news_092187' 3]
#  ['支持陳前總統保外就醫' 'news_033993' 1]
#  ['支持陳前總統保外就醫' 'news_073850' 3]
#  ['支持陳前總統保外就醫' 'news_095400' 2]
#  ['支持陳前總統保外就醫' 'news_066906' 2]
#  ['支持陳前總統保外就醫' 'news_027836' 2]
#  ['支持陳前總統保外就醫' 'news_023544' 2]
#  ['支持陳前總統保外就醫' 'news_077662' 2]
#  ['支持陳前總統保外就醫' 'news_093795' 1]
#  ['支持陳前總統保外就醫' 'news_000801' 3]
#  ['支持陳前總統保外就醫' 'news_044312' 1]
#  ['支持陳前總統保外就醫' 'news_073697' 3]
#  ['支持陳前總統保外就醫' 'news_029033' 2]
#  ['支持陳前總統保外就醫' 'news_018007' 3]
#  ['支持陳前總統保外就醫' 'news_088466' 3]
#  ['支持陳前總統保外就醫' 'news_029629' 2]
#  ['支持陳前總統保外就醫' 'news_004452' 2]
#  ['支持陳前總統保外就醫' 'news_080110' 1]
#  ['支持陳前總統保外就醫' 'news_086612' 2]
#  ['支持陳前總統保外就醫' 'news_049121' 2]
#  ['支持陳前總統保外就醫' 'news_070458' 1]
#  ['支持陳前總統保外就醫' 'news_063881' 1]
#  ['支持陳前總統保外就醫' 'news_035665' 1]
#  ['支持陳前總統保外就醫' 'news_061769' 2]
#  ['支持陳前總統保外就醫' 'news_089172' 3]
#  ['支持陳前總統保外就醫' 'news_060312' 3]
#  ['支持陳前總統保外就醫' 'news_087791' 2]
#  ['支持陳前總統保外就醫' 'news_079271' 3]
#  ['支持陳前總統保外就醫' 'news_013344' 1]
#  ['支持陳前總統保外就醫' 'news_037812' 2]
#  ['支持陳前總統保外就醫' 'news_031161' 1]
#  ['支持陳前總統保外就醫' 'news_069668' 2]
#  ['支持陳前總統保外就醫' 'news_021348' 3]
#  ['支持陳前總統保外就醫' 'news_026664' 1]
#  ['支持陳前總統保外就醫' 'news_027911' 2]
#  ['支持陳前總統保外就醫' 'news_095488' 3]
#  ['支持陳前總統保外就醫' 'news_063859' 2]
#  ['支持陳前總統保外就醫' 'news_037735' 2]
#  ['支持陳前總統保外就醫' 'news_049982' 3]
#  ['支持陳前總統保外就醫' 'news_040999' 2]
#  ['支持陳前總統保外就醫' 'news_096074' 1]
#  ['支持陳前總統保外就醫' 'news_011884' 3]
#  ['支持陳前總統保外就醫' 'news_087333' 3]
#  ['支持陳前總統保外就醫' 'news_068401' 3]
#  ['支持陳前總統保外就醫' 'news_094034' 1]
#  ['支持陳前總統保外就醫' 'news_080079' 2]
#  ['支持陳前總統保外就醫' 'news_063470' 3]
#  ['支持陳前總統保外就醫' 'news_023368' 3]
#  ['支持陳前總統保外就醫' 'news_025152' 3]
#  ['支持陳前總統保外就醫' 'news_035076' 1]
#  ['支持陳前總統保外就醫' 'news_092224' 2]
#  ['支持陳前總統保外就醫' 'news_031657' 3]
#  ['支持陳前總統保外就醫' 'news_008239' 2]
#  ['支持陳前總統保外就醫' 'news_022328' 1]
#  ['支持陳前總統保外就醫' 'news_071592' 1]
#  ['支持陳前總統保外就醫' 'news_033656' 3]
#  ['支持陳前總統保外就醫' 'news_050840' 1]
#  ['支持陳前總統保外就醫' 'news_068629' 2]
#  ['支持陳前總統保外就醫' 'news_084891' 1]
#  ['支持陳前總統保外就醫' 'news_054837' 2]
#  ['支持陳前總統保外就醫' 'news_002953' 1]
#  ['支持陳前總統保外就醫' 'news_037931' 2]
#  ['支持陳前總統保外就醫' 'news_032713' 3]
#  ['支持陳前總統保外就醫' 'news_030269' 2]
#  ['支持陳前總統保外就醫' 'news_047719' 3]
#  ['支持陳前總統保外就醫' 'news_036152' 3]
#  ['支持陳前總統保外就醫' 'news_080862' 1]
#  ['支持陳前總統保外就醫' 'news_012842' 1]
#  ['支持陳前總統保外就醫' 'news_049375' 1]
#  ['支持陳前總統保外就醫' 'news_040887' 3]
#  ['支持陳前總統保外就醫' 'news_001477' 1]
#  ['支持陳前總統保外就醫' 'news_017097' 2]
#  ['支持陳前總統保外就醫' 'news_018219' 3]
#  ['支持陳前總統保外就醫' 'news_011406' 3]
#  ['支持陳前總統保外就醫' 'news_046384' 2]
#  ['支持陳前總統保外就醫' 'news_002641' 1]
#  ['支持陳前總統保外就醫' 'news_040496' 2]
#  ['支持陳前總統保外就醫' 'news_045216' 1]
#  ['支持陳前總統保外就醫' 'news_050266' 3]
#  ['支持陳前總統保外就醫' 'news_008581' 2]
#  ['支持陳前總統保外就醫' 'news_076407' 2]
#  ['支持陳前總統保外就醫' 'news_026399' 1]
#  ['支持陳前總統保外就醫' 'news_078687' 2]
#  ['支持陳前總統保外就醫' 'news_071379' 1]
#  ['支持陳前總統保外就醫' 'news_053017' 1]
#  ['支持陳前總統保外就醫' 'news_061767' 3]
#  ['支持陳前總統保外就醫' 'news_082627' 2]
#  ['支持陳前總統保外就醫' 'news_083673' 2]
#  ['支持陳前總統保外就醫' 'news_055767' 3]
#  ['支持陳前總統保外就醫' 'news_081412' 3]
#  ['支持陳前總統保外就醫' 'news_003778' 1]
#  ['支持陳前總統保外就醫' 'news_076655' 3]
#  ['支持陳前總統保外就醫' 'news_092458' 2]
#  ['支持陳前總統保外就醫' 'news_097020' 3]
#  ['支持陳前總統保外就醫' 'news_018751' 3]
#  ['支持陳前總統保外就醫' 'news_007757' 1]
#  ['支持陳前總統保外就醫' 'news_070753' 2]
#  ['支持陳前總統保外就醫' 'news_079561' 2]
#  ['支持陳前總統保外就醫' 'news_009434' 2]
#  ['支持陳前總統保外就醫' 'news_001027' 1]
#  ['支持陳前總統保外就醫' 'news_000484' 3]
#  ['支持陳前總統保外就醫' 'news_047138' 2]
#  ['支持陳前總統保外就醫' 'news_045332' 2]
#  ['支持陳前總統保外就醫' 'news_037630' 2]
#  ['支持陳前總統保外就醫' 'news_084805' 3]
#  ['支持陳前總統保外就醫' 'news_007018' 3]
#  ['支持陳前總統保外就醫' 'news_064343' 3]
#  ['支持陳前總統保外就醫' 'news_098620' 1]
#  ['支持陳前總統保外就醫' 'news_011670' 1]
#  ['支持陳前總統保外就醫' 'news_059236' 2]
#  ['支持陳前總統保外就醫' 'news_073316' 1]
#  ['支持陳前總統保外就醫' 'news_023772' 2]
#  ['支持陳前總統保外就醫' 'news_054750' 1]
#  ['支持陳前總統保外就醫' 'news_047525' 3]
#  ['支持陳前總統保外就醫' 'news_076328' 2]
#  ['支持陳前總統保外就醫' 'news_032762' 3]
#  ['支持陳前總統保外就醫' 'news_044256' 1]
#  ['支持陳前總統保外就醫' 'news_044673' 1]
#  ['支持陳前總統保外就醫' 'news_019993' 1]
#  ['支持陳前總統保外就醫' 'news_043681' 3]
#  ['支持陳前總統保外就醫' 'news_092272' 3]
#  ['支持陳前總統保外就醫' 'news_018655' 2]
#  ['支持陳前總統保外就醫' 'news_093827' 2]
#  ['支持陳前總統保外就醫' 'news_000355' 2]
#  ['支持陳前總統保外就醫' 'news_023043' 3]
#  ['支持陳前總統保外就醫' 'news_032853' 2]
#  ['支持陳前總統保外就醫' 'news_097947' 1]
#  ['支持陳前總統保外就醫' 'news_073035' 3]
#  ['支持陳前總統保外就醫' 'news_078350' 1]
#  ['支持陳前總統保外就醫' 'news_067714' 3]
#  ['支持陳前總統保外就醫' 'news_077570' 1]
#  ['支持陳前總統保外就醫' 'news_027606' 2]
#  ['支持陳前總統保外就醫' 'news_010325' 1]
#  ['支持陳前總統保外就醫' 'news_037623' 2]
#  ['支持陳前總統保外就醫' 'news_019639' 2]
#  ['支持陳前總統保外就醫' 'news_079219' 2]
#  ['支持陳前總統保外就醫' 'news_063938' 2]
#  ['支持陳前總統保外就醫' 'news_063469' 3]
#  ['支持陳前總統保外就醫' 'news_076874' 2]
#  ['支持陳前總統保外就醫' 'news_024008' 3]
#  ['支持陳前總統保外就醫' 'news_008528' 1]
#  ['支持陳前總統保外就醫' 'news_013113' 1]
#  ['支持陳前總統保外就醫' 'news_089722' 2]
#  ['支持陳前總統保外就醫' 'news_036408' 3]
#  ['支持陳前總統保外就醫' 'news_021925' 2]
#  ['支持陳前總統保外就醫' 'news_025193' 3]
#  ['支持陳前總統保外就醫' 'news_042169' 1]
#  ['支持陳前總統保外就醫' 'news_089020' 1]
#  ['支持陳前總統保外就醫' 'news_092277' 2]
#  ['支持陳前總統保外就醫' 'news_054341' 3]
#  ['支持陳前總統保外就醫' 'news_046750' 1]
#  ['支持陳前總統保外就醫' 'news_020153' 3]
#  ['支持陳前總統保外就醫' 'news_026581' 2]
#  ['支持陳前總統保外就醫' 'news_098852' 3]
#  ['支持陳前總統保外就醫' 'news_047626' 2]
#  ['支持陳前總統保外就醫' 'news_017995' 2]
#  ['支持陳前總統保外就醫' 'news_085079' 2]
#  ['支持陳前總統保外就醫' 'news_004671' 1]
#  ['支持陳前總統保外就醫' 'news_096313' 3]
#  ['支持陳前總統保外就醫' 'news_014099' 3]
#  ['支持陳前總統保外就醫' 'news_084727' 2]
#  ['支持陳前總統保外就醫' 'news_064660' 1]
#  ['支持陳前總統保外就醫' 'news_087859' 3]
#  ['支持陳前總統保外就醫' 'news_031545' 1]
#  ['支持陳前總統保外就醫' 'news_092795' 2]
#  ['支持陳前總統保外就醫' 'news_045372' 2]
#  ['支持陳前總統保外就醫' 'news_028048' 1]
#  ['支持陳前總統保外就醫' 'news_087511' 0]
#  ['支持陳前總統保外就醫' 'news_051773' 0]
#  ['支持陳前總統保外就醫' 'news_019856' 0]
#  ['支持陳前總統保外就醫' 'news_048504' 0]
#  ['支持陳前總統保外就醫' 'news_047261' 0]
#  ['支持陳前總統保外就醫' 'news_079685' 0]
#  ['支持陳前總統保外就醫' 'news_033318' 0]
#  ['支持陳前總統保外就醫' 'news_096011' 0]
#  ['支持陳前總統保外就醫' 'news_047658' 0]
#  ['支持陳前總統保外就醫' 'news_060703' 0]
#  ['支持陳前總統保外就醫' 'news_078728' 0]
#  ['支持陳前總統保外就醫' 'news_098432' 0]
#  ['支持陳前總統保外就醫' 'news_047244' 0]
#  ['支持陳前總統保外就醫' 'news_040724' 0]
#  ['支持陳前總統保外就醫' 'news_015346' 0]
#  ['支持陳前總統保外就醫' 'news_086801' 0]
#  ['支持陳前總統保外就醫' 'news_054993' 0]
#  ['支持陳前總統保外就醫' 'news_029593' 0]
#  ['支持陳前總統保外就醫' 'news_030642' 0]
#  ['支持陳前總統保外就醫' 'news_014437' 0]
#  ['支持陳前總統保外就醫' 'news_089034' 0]
#  ['支持陳前總統保外就醫' 'news_025615' 0]
#  ['支持陳前總統保外就醫' 'news_068001' 0]
#  ['支持陳前總統保外就醫' 'news_097547' 0]
#  ['支持陳前總統保外就醫' 'news_034566' 0]
#  ['支持陳前總統保外就醫' 'news_032884' 0]
#  ['支持陳前總統保外就醫' 'news_078099' 0]
#  ['支持陳前總統保外就醫' 'news_090904' 0]
#  ['支持陳前總統保外就醫' 'news_033716' 0]
#  ['支持陳前總統保外就醫' 'news_031569' 0]]
# 0.04634799632762461
# [['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_038482' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_002728' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_087044' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_097531' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_088594' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_042072' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_016422' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_064842' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_081266' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_047982' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_075769' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_018827' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_063539' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_006420' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_048327' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_048648' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_021217' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_095595' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_023763' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_069462' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_073552' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_005600' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_011407' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_099484' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_042122' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_052739' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_029877' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_022453' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_030172' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_088267' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_075199' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_027518' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_014796' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_024980' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_099415' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_007054' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_034621' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_008644' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_054103' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_002939' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_044880' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_049473' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_002862' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_041878' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_030211' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_017574' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_077373' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_008889' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_028848' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_099443' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_097102' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_031372' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_063446' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_089230' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_006636' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_097262' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_063979' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_095233' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_053480' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_067624' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_018478' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_052098' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_044341' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_082329' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_052560' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_006152' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_077230' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_006179' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_037867' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_047147' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_051949' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_047429' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_042470' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_023228' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_023738' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_087808' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_062680' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_034914' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_065286' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_062413' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_028276' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_094532' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_003983' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_006533' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_066018' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_017144' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_055201' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_081704' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_000086' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_029357' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_013448' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_013071' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_002519' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_058095' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_061186' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_055006' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_031048' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_026385' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_054707' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_058009' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_060087' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_034159' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_048922' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_064430' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_088352' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_021553' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_025966' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_009981' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_094728' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_058180' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_070084' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_032165' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_038056' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_083723' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_055470' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_021136' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_055276' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_031847' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_025957' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_096125' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_060291' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_005488' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_037958' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_083179' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_038172' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_041184' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_067366' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_041337' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_078410' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_073471' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_033513' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_002307' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_087095' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_026832' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_017653' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_096804' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_015890' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_099928' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_063387' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_063709' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_056167' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_003636' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_094127' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_082821' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_003161' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_047171' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_013749' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_040924' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_040594' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_085515' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_025364' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_085608' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_090563' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_046782' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_032231' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_061840' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_054285' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_060408' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_015836' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_099288' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_081895' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_084759' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_061131' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_052300' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_088204' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_011178' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_092607' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_080161' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_065486' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_055974' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_077914' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_098358' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_025036' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_098612' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_069874' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_043777' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_019814' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_069293' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_072848' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_085478' 3]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_029065' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_024120' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_027660' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_092064' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_079829' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_010155' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_056013' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_005852' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_075114' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_026640' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_064828' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_029633' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_007680' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_013289' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_032654' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_000577' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_069024' 2]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_038275' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_092568' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_046961' 1]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_033019' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_093482' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_097526' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_024845' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_081081' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_015941' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_069367' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_062283' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_051022' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_048164' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_024774' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_047512' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_021315' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_061626' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_039781' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_051894' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_087086' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_095311' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_004467' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_097061' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_070907' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_040339' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_015293' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_015071' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_005909' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_002778' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_037523' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_013172' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_054510' 0]
#  ['年金改革應取消或應調降軍公教月退之優存利率十八趴' 'news_012241' 0]]
# 0.08380145662282511
# [['同意動物實驗' 'news_093936' 2]
#  ['同意動物實驗' 'news_039323' 2]
#  ['同意動物實驗' 'news_055047' 3]
#  ['同意動物實驗' 'news_071517' 2]
#  ['同意動物實驗' 'news_062115' 1]
#  ['同意動物實驗' 'news_063285' 2]
#  ['同意動物實驗' 'news_020421' 1]
#  ['同意動物實驗' 'news_036196' 3]
#  ['同意動物實驗' 'news_025388' 3]
#  ['同意動物實驗' 'news_066824' 3]
#  ['同意動物實驗' 'news_061647' 1]
#  ['同意動物實驗' 'news_023819' 3]
#  ['同意動物實驗' 'news_004497' 2]
#  ['同意動物實驗' 'news_013392' 3]
#  ['同意動物實驗' 'news_054482' 2]
#  ['同意動物實驗' 'news_055942' 2]
#  ['同意動物實驗' 'news_031781' 2]
#  ['同意動物實驗' 'news_085537' 2]
#  ['同意動物實驗' 'news_027095' 2]
#  ['同意動物實驗' 'news_051364' 1]
#  ['同意動物實驗' 'news_033732' 0]
#  ['同意動物實驗' 'news_037248' 0]
#  ['同意動物實驗' 'news_077119' 0]
#  ['同意動物實驗' 'news_052568' 0]
#  ['同意動物實驗' 'news_013000' 0]
#  ['同意動物實驗' 'news_063227' 0]
#  ['同意動物實驗' 'news_017528' 0]
#  ['同意動物實驗' 'news_058387' 0]
#  ['同意動物實驗' 'news_081185' 0]
#  ['同意動物實驗' 'news_099004' 0]
#  ['同意動物實驗' 'news_016253' 0]
#  ['同意動物實驗' 'news_062371' 0]
#  ['同意動物實驗' 'news_000884' 0]
#  ['同意動物實驗' 'news_046330' 0]
#  ['同意動物實驗' 'news_059972' 0]
#  ['同意動物實驗' 'news_019211' 0]
#  ['同意動物實驗' 'news_054414' 0]
#  ['同意動物實驗' 'news_047844' 0]
#  ['同意動物實驗' 'news_080852' 0]
#  ['同意動物實驗' 'news_099013' 0]]
# 0.23460161046953382
# [['油價應該凍漲或緩漲' 'news_024001' 1]
#  ['油價應該凍漲或緩漲' 'news_090765' 1]
#  ['油價應該凍漲或緩漲' 'news_094552' 1]
#  ['油價應該凍漲或緩漲' 'news_020793' 1]
#  ['油價應該凍漲或緩漲' 'news_098787' 1]
#  ['油價應該凍漲或緩漲' 'news_032365' 1]
#  ['油價應該凍漲或緩漲' 'news_095927' 1]
#  ['油價應該凍漲或緩漲' 'news_050615' 1]
#  ['油價應該凍漲或緩漲' 'news_038657' 1]
#  ['油價應該凍漲或緩漲' 'news_047875' 1]
#  ['油價應該凍漲或緩漲' 'news_059745' 2]
#  ['油價應該凍漲或緩漲' 'news_013547' 1]
#  ['油價應該凍漲或緩漲' 'news_034563' 1]
#  ['油價應該凍漲或緩漲' 'news_009958' 1]
#  ['油價應該凍漲或緩漲' 'news_017345' 1]
#  ['油價應該凍漲或緩漲' 'news_060277' 1]
#  ['油價應該凍漲或緩漲' 'news_012605' 1]
#  ['油價應該凍漲或緩漲' 'news_060707' 1]
#  ['油價應該凍漲或緩漲' 'news_085579' 1]
#  ['油價應該凍漲或緩漲' 'news_068959' 1]
#  ['油價應該凍漲或緩漲' 'news_076823' 1]
#  ['油價應該凍漲或緩漲' 'news_089252' 1]
#  ['油價應該凍漲或緩漲' 'news_027192' 1]
#  ['油價應該凍漲或緩漲' 'news_059361' 1]
#  ['油價應該凍漲或緩漲' 'news_083285' 1]
#  ['油價應該凍漲或緩漲' 'news_067014' 1]
#  ['油價應該凍漲或緩漲' 'news_098356' 1]
#  ['油價應該凍漲或緩漲' 'news_065602' 1]
#  ['油價應該凍漲或緩漲' 'news_036716' 1]
#  ['油價應該凍漲或緩漲' 'news_015325' 1]
#  ['油價應該凍漲或緩漲' 'news_081790' 1]
#  ['油價應該凍漲或緩漲' 'news_036497' 1]
#  ['油價應該凍漲或緩漲' 'news_047553' 1]
#  ['油價應該凍漲或緩漲' 'news_061258' 1]
#  ['油價應該凍漲或緩漲' 'news_057731' 1]
#  ['油價應該凍漲或緩漲' 'news_040721' 1]
#  ['油價應該凍漲或緩漲' 'news_021369' 1]
#  ['油價應該凍漲或緩漲' 'news_099310' 1]
#  ['油價應該凍漲或緩漲' 'news_089375' 1]
#  ['油價應該凍漲或緩漲' 'news_056892' 1]
#  ['油價應該凍漲或緩漲' 'news_076152' 1]
#  ['油價應該凍漲或緩漲' 'news_044032' 1]
#  ['油價應該凍漲或緩漲' 'news_006020' 1]
#  ['油價應該凍漲或緩漲' 'news_064331' 1]
#  ['油價應該凍漲或緩漲' 'news_034405' 1]
#  ['油價應該凍漲或緩漲' 'news_094936' 1]
#  ['油價應該凍漲或緩漲' 'news_093325' 1]
#  ['油價應該凍漲或緩漲' 'news_046602' 1]
#  ['油價應該凍漲或緩漲' 'news_005838' 1]
#  ['油價應該凍漲或緩漲' 'news_011983' 1]
#  ['油價應該凍漲或緩漲' 'news_013053' 1]
#  ['油價應該凍漲或緩漲' 'news_031344' 1]
#  ['油價應該凍漲或緩漲' 'news_080408' 1]
#  ['油價應該凍漲或緩漲' 'news_078374' 1]
#  ['油價應該凍漲或緩漲' 'news_043840' 1]
#  ['油價應該凍漲或緩漲' 'news_026711' 1]
#  ['油價應該凍漲或緩漲' 'news_020542' 1]
#  ['油價應該凍漲或緩漲' 'news_048373' 1]
#  ['油價應該凍漲或緩漲' 'news_054373' 1]
#  ['油價應該凍漲或緩漲' 'news_086892' 1]
#  ['油價應該凍漲或緩漲' 'news_095401' 1]
#  ['油價應該凍漲或緩漲' 'news_010804' 1]
#  ['油價應該凍漲或緩漲' 'news_010690' 1]
#  ['油價應該凍漲或緩漲' 'news_075504' 1]
#  ['油價應該凍漲或緩漲' 'news_060022' 1]
#  ['油價應該凍漲或緩漲' 'news_013436' 1]
#  ['油價應該凍漲或緩漲' 'news_021666' 1]
#  ['油價應該凍漲或緩漲' 'news_093367' 1]
#  ['油價應該凍漲或緩漲' 'news_053105' 0]
#  ['油價應該凍漲或緩漲' 'news_074825' 0]
#  ['油價應該凍漲或緩漲' 'news_018469' 0]
#  ['油價應該凍漲或緩漲' 'news_009069' 0]
#  ['油價應該凍漲或緩漲' 'news_000897' 0]
#  ['油價應該凍漲或緩漲' 'news_087720' 0]
#  ['油價應該凍漲或緩漲' 'news_021531' 0]
#  ['油價應該凍漲或緩漲' 'news_069974' 0]
#  ['油價應該凍漲或緩漲' 'news_078416' 0]
#  ['油價應該凍漲或緩漲' 'news_080402' 0]
#  ['油價應該凍漲或緩漲' 'news_013167' 0]
#  ['油價應該凍漲或緩漲' 'news_021274' 0]
#  ['油價應該凍漲或緩漲' 'news_025311' 0]
#  ['油價應該凍漲或緩漲' 'news_079055' 0]
#  ['油價應該凍漲或緩漲' 'news_051976' 0]
#  ['油價應該凍漲或緩漲' 'news_045995' 0]
#  ['油價應該凍漲或緩漲' 'news_081630' 0]
#  ['油價應該凍漲或緩漲' 'news_031123' 0]
#  ['油價應該凍漲或緩漲' 'news_003320' 0]
#  ['油價應該凍漲或緩漲' 'news_089771' 0]
#  ['油價應該凍漲或緩漲' 'news_022718' 0]
#  ['油價應該凍漲或緩漲' 'news_010203' 0]
#  ['油價應該凍漲或緩漲' 'news_033893' 0]
#  ['油價應該凍漲或緩漲' 'news_013271' 0]
#  ['油價應該凍漲或緩漲' 'news_025470' 0]
#  ['油價應該凍漲或緩漲' 'news_006539' 0]
#  ['油價應該凍漲或緩漲' 'news_065767' 0]]
# 0.11882903347052173
# [['反對旺旺中時併購中嘉' 'news_099776' 3]
#  ['反對旺旺中時併購中嘉' 'news_081357' 2]
#  ['反對旺旺中時併購中嘉' 'news_095391' 3]
#  ['反對旺旺中時併購中嘉' 'news_059833' 1]
#  ['反對旺旺中時併購中嘉' 'news_043384' 2]
#  ['反對旺旺中時併購中嘉' 'news_086309' 1]
#  ['反對旺旺中時併購中嘉' 'news_028094' 2]
#  ['反對旺旺中時併購中嘉' 'news_006796' 1]
#  ['反對旺旺中時併購中嘉' 'news_088488' 1]
#  ['反對旺旺中時併購中嘉' 'news_006102' 2]
#  ['反對旺旺中時併購中嘉' 'news_047256' 3]
#  ['反對旺旺中時併購中嘉' 'news_073266' 1]
#  ['反對旺旺中時併購中嘉' 'news_003422' 1]
#  ['反對旺旺中時併購中嘉' 'news_060027' 3]
#  ['反對旺旺中時併購中嘉' 'news_099537' 2]
#  ['反對旺旺中時併購中嘉' 'news_085416' 2]
#  ['反對旺旺中時併購中嘉' 'news_097441' 2]
#  ['反對旺旺中時併購中嘉' 'news_028702' 1]
#  ['反對旺旺中時併購中嘉' 'news_075891' 1]
#  ['反對旺旺中時併購中嘉' 'news_066569' 1]
#  ['反對旺旺中時併購中嘉' 'news_055212' 3]
#  ['反對旺旺中時併購中嘉' 'news_084802' 3]
#  ['反對旺旺中時併購中嘉' 'news_070743' 1]
#  ['反對旺旺中時併購中嘉' 'news_053481' 2]
#  ['反對旺旺中時併購中嘉' 'news_052634' 1]
#  ['反對旺旺中時併購中嘉' 'news_033926' 3]
#  ['反對旺旺中時併購中嘉' 'news_040878' 1]
#  ['反對旺旺中時併購中嘉' 'news_091643' 1]
#  ['反對旺旺中時併購中嘉' 'news_040320' 1]
#  ['反對旺旺中時併購中嘉' 'news_023479' 2]
#  ['反對旺旺中時併購中嘉' 'news_082024' 1]
#  ['反對旺旺中時併購中嘉' 'news_099287' 3]
#  ['反對旺旺中時併購中嘉' 'news_065652' 3]
#  ['反對旺旺中時併購中嘉' 'news_065824' 3]
#  ['反對旺旺中時併購中嘉' 'news_030910' 1]
#  ['反對旺旺中時併購中嘉' 'news_078622' 1]
#  ['反對旺旺中時併購中嘉' 'news_017193' 2]
#  ['反對旺旺中時併購中嘉' 'news_044250' 2]
#  ['反對旺旺中時併購中嘉' 'news_054885' 1]
#  ['反對旺旺中時併購中嘉' 'news_057241' 3]
#  ['反對旺旺中時併購中嘉' 'news_066650' 1]
#  ['反對旺旺中時併購中嘉' 'news_045571' 1]
#  ['反對旺旺中時併購中嘉' 'news_096220' 2]
#  ['反對旺旺中時併購中嘉' 'news_044151' 1]
#  ['反對旺旺中時併購中嘉' 'news_007458' 3]
#  ['反對旺旺中時併購中嘉' 'news_015341' 1]
#  ['反對旺旺中時併購中嘉' 'news_058880' 3]
#  ['反對旺旺中時併購中嘉' 'news_003463' 3]
#  ['反對旺旺中時併購中嘉' 'news_008196' 1]
#  ['反對旺旺中時併購中嘉' 'news_005130' 1]
#  ['反對旺旺中時併購中嘉' 'news_027772' 3]
#  ['反對旺旺中時併購中嘉' 'news_063310' 1]
#  ['反對旺旺中時併購中嘉' 'news_086489' 2]
#  ['反對旺旺中時併購中嘉' 'news_023177' 3]
#  ['反對旺旺中時併購中嘉' 'news_056750' 1]
#  ['反對旺旺中時併購中嘉' 'news_040501' 1]
#  ['反對旺旺中時併購中嘉' 'news_088058' 1]
#  ['反對旺旺中時併購中嘉' 'news_032092' 3]
#  ['反對旺旺中時併購中嘉' 'news_026140' 1]
#  ['反對旺旺中時併購中嘉' 'news_020116' 1]
#  ['反對旺旺中時併購中嘉' 'news_078248' 1]
#  ['反對旺旺中時併購中嘉' 'news_073829' 1]
#  ['反對旺旺中時併購中嘉' 'news_080646' 2]
#  ['反對旺旺中時併購中嘉' 'news_003963' 3]
#  ['反對旺旺中時併購中嘉' 'news_020486' 3]
#  ['反對旺旺中時併購中嘉' 'news_044916' 3]
#  ['反對旺旺中時併購中嘉' 'news_074060' 2]
#  ['反對旺旺中時併購中嘉' 'news_081546' 2]
#  ['反對旺旺中時併購中嘉' 'news_019279' 2]
#  ['反對旺旺中時併購中嘉' 'news_016705' 1]
#  ['反對旺旺中時併購中嘉' 'news_027917' 3]
#  ['反對旺旺中時併購中嘉' 'news_059005' 2]
#  ['反對旺旺中時併購中嘉' 'news_055312' 1]
#  ['反對旺旺中時併購中嘉' 'news_078437' 1]
#  ['反對旺旺中時併購中嘉' 'news_089977' 3]
#  ['反對旺旺中時併購中嘉' 'news_062054' 3]
#  ['反對旺旺中時併購中嘉' 'news_005395' 3]
#  ['反對旺旺中時併購中嘉' 'news_024926' 3]
#  ['反對旺旺中時併購中嘉' 'news_071647' 1]
#  ['反對旺旺中時併購中嘉' 'news_052116' 2]
#  ['反對旺旺中時併購中嘉' 'news_036242' 3]
#  ['反對旺旺中時併購中嘉' 'news_030486' 1]
#  ['反對旺旺中時併購中嘉' 'news_068588' 1]
#  ['反對旺旺中時併購中嘉' 'news_047510' 2]
#  ['反對旺旺中時併購中嘉' 'news_030443' 2]
#  ['反對旺旺中時併購中嘉' 'news_023990' 3]
#  ['反對旺旺中時併購中嘉' 'news_096667' 1]
#  ['反對旺旺中時併購中嘉' 'news_005353' 3]
#  ['反對旺旺中時併購中嘉' 'news_097392' 3]
#  ['反對旺旺中時併購中嘉' 'news_089903' 1]
#  ['反對旺旺中時併購中嘉' 'news_098171' 3]
#  ['反對旺旺中時併購中嘉' 'news_031385' 3]
#  ['反對旺旺中時併購中嘉' 'news_010508' 2]
#  ['反對旺旺中時併購中嘉' 'news_051598' 3]
#  ['反對旺旺中時併購中嘉' 'news_029153' 3]
#  ['反對旺旺中時併購中嘉' 'news_076927' 3]
#  ['反對旺旺中時併購中嘉' 'news_027307' 1]
#  ['反對旺旺中時併購中嘉' 'news_028585' 3]
#  ['反對旺旺中時併購中嘉' 'news_037723' 1]
#  ['反對旺旺中時併購中嘉' 'news_025912' 2]
#  ['反對旺旺中時併購中嘉' 'news_099801' 1]
#  ['反對旺旺中時併購中嘉' 'news_055087' 1]
#  ['反對旺旺中時併購中嘉' 'news_080644' 1]
#  ['反對旺旺中時併購中嘉' 'news_092217' 2]
#  ['反對旺旺中時併購中嘉' 'news_067177' 1]
#  ['反對旺旺中時併購中嘉' 'news_034248' 1]
#  ['反對旺旺中時併購中嘉' 'news_046785' 3]
#  ['反對旺旺中時併購中嘉' 'news_090281' 2]
#  ['反對旺旺中時併購中嘉' 'news_031605' 3]
#  ['反對旺旺中時併購中嘉' 'news_096364' 0]
#  ['反對旺旺中時併購中嘉' 'news_080297' 0]
#  ['反對旺旺中時併購中嘉' 'news_001305' 0]
#  ['反對旺旺中時併購中嘉' 'news_044481' 0]
#  ['反對旺旺中時併購中嘉' 'news_039161' 0]
#  ['反對旺旺中時併購中嘉' 'news_031057' 0]
#  ['反對旺旺中時併購中嘉' 'news_012569' 0]
#  ['反對旺旺中時併購中嘉' 'news_051678' 0]
#  ['反對旺旺中時併購中嘉' 'news_080068' 0]
#  ['反對旺旺中時併購中嘉' 'news_020119' 0]
#  ['反對旺旺中時併購中嘉' 'news_035107' 0]
#  ['反對旺旺中時併購中嘉' 'news_038080' 0]
#  ['反對旺旺中時併購中嘉' 'news_050323' 0]
#  ['反對旺旺中時併購中嘉' 'news_036689' 0]
#  ['反對旺旺中時併購中嘉' 'news_093391' 0]
#  ['反對旺旺中時併購中嘉' 'news_072647' 0]
#  ['反對旺旺中時併購中嘉' 'news_032342' 0]
#  ['反對旺旺中時併購中嘉' 'news_000445' 0]
#  ['反對旺旺中時併購中嘉' 'news_027966' 0]
#  ['反對旺旺中時併購中嘉' 'news_036335' 0]
#  ['反對旺旺中時併購中嘉' 'news_044773' 0]
#  ['反對旺旺中時併購中嘉' 'news_030239' 0]
#  ['反對旺旺中時併購中嘉' 'news_053863' 0]
#  ['反對旺旺中時併購中嘉' 'news_036128' 0]
#  ['反對旺旺中時併購中嘉' 'news_022887' 0]
#  ['反對旺旺中時併購中嘉' 'news_064525' 0]
#  ['反對旺旺中時併購中嘉' 'news_035906' 0]
#  ['反對旺旺中時併購中嘉' 'news_064672' 0]
#  ['反對旺旺中時併購中嘉' 'news_012209' 0]
#  ['反對旺旺中時併購中嘉' 'news_070387' 0]]
# 0.11555958386039389
# MAP = 0.11982793615017984
